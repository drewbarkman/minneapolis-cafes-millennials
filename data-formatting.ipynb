# %% [markdown]
# # Data Formatting

# %% [markdown]
# ## Step One: Pull Millennial Count from Age Data

# %%
import pandas as pd
import geopandas as gpd

# %%
age_df = pd.read_csv('raw-data/age-data-by-neighborhood.csv', encoding='utf-16-le', sep='\t')
age_df.head()
# Out:
#                           Dashboard Name       Page ACS 5 Label Table ID  \
# 0  Minneapolis Neighborhood Demographics  Age Range   2018-2022   B01001
# 1  Minneapolis Neighborhood Demographics  Age Range   2018-2022   B01001
# 2  Minneapolis Neighborhood Demographics  Age Range   2018-2022   B01001
# 3  Minneapolis Neighborhood Demographics  Age Range   2018-2022   B01001
# 4  Minneapolis Neighborhood Demographics  Age Range   2018-2022   B01001
#
#   Neighborhood Name  Description 1  Description 2  Description 3  \
# 0          Armatage  10 - 17 years            NaN            NaN
# 1          Armatage  10 - 17 years            NaN            NaN
# 2          Armatage  10 - 17 years            NaN            NaN
# 3          Armatage  10 - 17 years            NaN            NaN
# 4          Armatage  10 - 17 years            NaN            NaN
#
#   Race/Ethnicity   Units          Universe Reliability Level  \
# 0            all  people  total population            Medium
# 1            all  people  total population            Medium
# 2            all  people  total population            Medium
# 3            all  people  total population            Medium
# 4            all  people  total population            Medium
#
#               Measure Names  Measure Values
# 0      Percent Universe MOE          0.0506
# 1          Percent Universe          0.1360
# 2           Margin of Error        295.0000
# 3                  Estimate        734.0000
# 4  Coefficient of Variation          0.2440

# %%
age_estimates = age_df[age_df['Measure Names'] == 'Estimate'][['Neighborhood Name', 'Description 1', 'Measure Values']]
age_estimates.head()
# Out:
#    Neighborhood Name  Description 1  Measure Values
# 3           Armatage  10 - 17 years           734.0
# 8           Armatage  18 - 24 years           173.0
# 13          Armatage  25 - 34 years           835.0
# 18          Armatage  35 - 49 years          1562.0
# 23          Armatage  50 - 64 years           723.0

# %% [markdown]
# In 2025, the ages of millennials are between 29-44. This is in the middle of two categories, so we will have to do some math to seperate the estimated count of millennials.
#
# 25-34: I need 29-34, subtracting 4 ages from the bracket, 4 ages out of 10 total, meaning I will use 60% of this category estimate.
#
# 35-49: I need 35-44, subtracting 5 ages from the bracket, 5 ages out of 15 total, meaning I will use 67% of this category estimate.

# %%
lower_age_bracket_estimate = (age_estimates
                              [age_estimates['Description 1'] == '25 - 34 years']
                              .groupby('Neighborhood Name')
                              ['Measure Values'].sum()
                                * .6)
lower_age_bracket_estimate.head()
# Out:
# Neighborhood Name
# Armatage        501.0
# Audubon Park    685.2
# Bancroft        398.4
# Beltrami        186.6
# Bottineau       308.4
# Name: Measure Values, dtype: float64

# %%
higher_age_bracket_estimate = (age_estimates
                              [age_estimates['Description 1'] == '35 - 49 years']
                              .groupby('Neighborhood Name')
                              ['Measure Values'].sum()
                                * .67)
higher_age_bracket_estimate.head()
# Out:
# Neighborhood Name
# Armatage        1046.54
# Audubon Park     960.11
# Bancroft         429.47
# Beltrami         146.06
# Bottineau        228.47
# Name: Measure Values, dtype: float64

# %%
total_counts = age_estimates.groupby('Neighborhood Name')['Measure Values'].sum()
total_counts.head()
# Out:
# Neighborhood Name
# Armatage        5396.0
# Audubon Park    5377.0
# Bancroft        2710.0
# Beltrami        1414.0
# Bottineau       1520.0
# Name: Measure Values, dtype: float64

# %%
millennial_counts = (lower_age_bracket_estimate + higher_age_bracket_estimate).round().rename_axis('BDNAME')
millennial_percent = pd.DataFrame(millennial_counts / total_counts).rename(columns={'Measure Values': 'MIL_PERCENT'})
millennial_percent.reset_index(inplace=True)
millennial_percent.head()
# Out:
#          BDNAME  MIL_PERCENT
# 0      Armatage     0.286879
# 1  Audubon Park     0.305933
# 2      Bancroft     0.305535
# 3      Beltrami     0.235502
# 4     Bottineau     0.353289

# %% [markdown]
# ## Step 2: Connect to GeoJSON File

# %% [markdown]
# First, I need to make sure neighborhood names match before I join them.

# %%
neighborhood_gdf = gpd.read_file('raw-data/minneapolis-neighborhoods.geojson')
neighborhood_gdf.head()
# Out:
#    OBJECTID   INT_REFNO PREFIX       UDI SYMBOL_NAM             BDNAME BDNUM  \
# 0         1 -2144134800  REFNO  23152.00   WARDAREA      Phillips West    90
# 1         2 -2144131300  REFNO  23187.00   WARDAREA      Downtown West    87
# 2         3 -2144131200  REFNO  23188.00   WARDAREA      Downtown East    88
# 3         4           0  REFNO  23189.00   WARDAREA    Ventura Village    89
# 4         5 -2144137100  REFNO  23129.00   WARDAREA  Sumner - Glenwood    29
#
#   TEXT_NBR                                           geometry
# 0       90  POLYGON ((-93.263 44.961, -93.263 44.961, -93....
# 1       87  POLYGON ((-93.26 44.983, -93.26 44.983, -93.26...
# 2       88  POLYGON ((-93.245 44.979, -93.245 44.979, -93....
# 3       89  POLYGON ((-93.25 44.966, -93.25 44.966, -93.24...
# 4       29  POLYGON ((-93.288 44.989, -93.288 44.989, -93....

# %%
gdf_names = set(neighborhood_gdf['BDNAME'])
df_names = set(millennial_percent['BDNAME'])

print(f'In neighboood file but no age data: {gdf_names - df_names}')
print(f'In data file but no neighborhood data: {df_names - gdf_names}')
# Out:
# In neighboood file but no age data: {'Humboldt Industrial Area'}
# In data file but no neighborhood data: set()

# %% [markdown]
# Since 'Humboldt Industrial Area' doesn't have age data in that dataset, I will take an average of the four surrounding neighborhoods, which I found using the neighborhood dataset (https://opendata.minneapolismn.gov/datasets/cityoflakes::minneapolis-neighborhoods/about)
#
# The four surrounding neighborhoods:
# - Shingle Creek
# - Lind - Bohanon
# - Webber - Camden
# - Victory

# %%
target_neighborhoods = ['Shingle Creek', 'Lind - Bohanon', 'Webber - Camden', 'Victory']

humboldt_neighbors = millennial_percent[millennial_percent['BDNAME'].isin(target_neighborhoods)]
humboldt_neighbors
# Out:
#              BDNAME  MIL_PERCENT
# 39   Lind - Bohanon     0.229563
# 67    Shingle Creek     0.214174
# 77          Victory     0.277113
# 79  Webber - Camden     0.233579

# %%
humboldt_row = {
    'BDNAME': 'Humboldt Industrial Area',
    'MIL_PERCENT': humboldt_neighbors['MIL_PERCENT'].mean()
}

millennial_percent = pd.concat([millennial_percent, pd.DataFrame([humboldt_row])], ignore_index=True, axis=0)
millennial_percent
# Out:
#                       BDNAME  MIL_PERCENT
# 0                   Armatage     0.286879
# 1               Audubon Park     0.305933
# 2                   Bancroft     0.305535
# 3                   Beltrami     0.235502
# 4                  Bottineau     0.353289
# ..                       ...          ...
# 82                  Whittier     0.321809
# 83             Willard - Hay     0.227832
# 84                    Windom     0.323186
# 85               Windom Park     0.304132
# 86  Humboldt Industrial Area     0.238607
#
# [87 rows x 2 columns]

# %%
neighborhood_gdf = pd.merge(neighborhood_gdf, millennial_percent)
neighborhood_gdf
# Out:
#     OBJECTID   INT_REFNO PREFIX       UDI SYMBOL_NAM             BDNAME BDNUM  \
# 0          1 -2144134800  REFNO  23152.00   WARDAREA      Phillips West    90
# 1          2 -2144131300  REFNO  23187.00   WARDAREA      Downtown West    87
# 2          3 -2144131200  REFNO  23188.00   WARDAREA      Downtown East    88
# 3          4           0  REFNO  23189.00   WARDAREA    Ventura Village    89
# 4          5 -2144137100  REFNO  23129.00   WARDAREA  Sumner - Glenwood    29
# ..       ...         ...    ...       ...        ...                ...   ...
# 82        83 -2144138700  REFNO  23113.00   WARDAREA   Marshall Terrace    13
# 83        84 -2144134900  REFNO  23151.00   WARDAREA           Whittier    51
# 84        85 -2144134700  REFNO  23153.00   WARDAREA            Lyndale    53
# 85        86 -2144135400  REFNO  23146.00   WARDAREA  East Bde Maka Ska    46
# 86        87 -2144135100  REFNO  23149.00   WARDAREA      West Maka Ska    49
#
#    TEXT_NBR                                           geometry  MIL_PERCENT
# 0        90  POLYGON ((-93.263 44.961, -93.263 44.961, -93....     0.225601
# 1        87  POLYGON ((-93.26 44.983, -93.26 44.983, -93.26...     0.370131
# 2        88  POLYGON ((-93.245 44.979, -93.245 44.979, -93....     0.256063
# 3        89  POLYGON ((-93.25 44.966, -93.25 44.966, -93.24...     0.191825
# 4        29  POLYGON ((-93.288 44.989, -93.288 44.989, -93....     0.248666
# ..      ...                                                ...          ...
# 82       13  POLYGON ((-93.278 45.028, -93.278 45.028, -93....     0.281103
# 83       51  POLYGON ((-93.27 44.963, -93.27 44.963, -93.27...     0.321809
# 84       53  POLYGON ((-93.284 44.948, -93.283 44.948, -93....     0.307311
# 85       46  POLYGON ((-93.302 44.948, -93.301 44.948, -93....     0.334332
# 86       49  POLYGON ((-93.327 44.948, -93.326 44.948, -93....     0.356811
#
# [87 rows x 10 columns]

# %%
neighborhood_gdf.to_file('formatted-age-data.geojson')
